# %%
dll_dir = r"C:\Users\abdul\Desktop\TUM\thesis\thesis\openslide-win64-20221111\bin"

import os
with os.add_dll_directory(dll_dir):
    from openslide import OpenSlide

# %%
image_dir = "sample_images"
image_names = os.listdir(image_dir)
images = [OpenSlide(os.path.join(image_dir, image_name)) for image_name in image_names]

# %%
images[0].get_thumbnail((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x183>
