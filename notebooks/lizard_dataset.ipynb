# %%
# %cd ..
# Out:
# c:\Users\abdul\Desktop\TUM\thesis\thesis

# %%
from src.dataset import LizardDataset
from matplotlib import pyplot as plt

# %%
dataset = LizardDataset(r'..\lizard\lizard_images', r'..\lizard\lizard_labels\Labels')

# %%
idx = 6
print(f"Number of neutrophils: {dataset.neutrophil_counts[idx]}")

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 10))
axes[0].imshow(dataset.images[idx])
axes[1].imshow(dataset.seg_maps[idx])
plt.show()
# Out:
# Number of neutrophils: 5
