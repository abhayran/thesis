# %%
# %cd ../..
# Out:
# c:\Users\abdul\Desktop\TUM\thesis\thesis

# %%
from src.unet.unet_torch import UNet
import torch

input_tensor = torch.randn(64, 3, 128, 128)
input_tensor
# Out:
# tensor([[[[-2.2247e-01,  1.3869e+00, -2.6455e-01,  ..., -4.3543e-01,
#             1.1614e+00, -1.5374e+00],
#           [-8.4547e-01, -7.1031e-01, -4.9567e-01,  ...,  8.8283e-01,
#             4.2639e-01,  1.1599e+00],
#           [ 9.9410e-01,  2.4563e-01, -3.9923e-01,  ...,  1.0133e+00,
#            -1.6949e-01,  1.8263e-01],
#           ...,
#           [ 1.0259e-02,  1.2784e-01, -4.1453e-02,  ..., -8.8276e-01,
#            -3.3400e-01, -7.9478e-01],
#           [-1.4299e-01, -9.8165e-01,  7.7439e-01,  ..., -1.0120e+00,
#             6.8077e-01, -1.0746e+00],
#           [-1.1390e+00, -1.1925e+00,  7.4514e-01,  ..., -1.6880e+00,
#            -5.4017e-01, -4.8697e-02]],
#
#          [[ 1.0550e+00,  1.6692e+00, -1.7783e-01,  ...,  1.4213e+00,
#             1.4961e+00,  2.3869e+00],
#           [-3.6685e-01, -4.4748e-01,  4.5526e-01,  ...,  2.2696e-01,
#            -3.6241e-01,  1.5502e+00],
#           [-1.4266e+00, -1.3040e+00,  7.4948e-01,  ...,  2.0297e+00,
# ...

# %%
model = UNet()
model
# Out:
# UNet(
#   (double_convs_encoder): ModuleList(
#     (0): DoubleConv(
#       (block): Sequential(
#         (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (1): DoubleConv(
#       (block): Sequential(
#         (0): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
model(input_tensor).shape
# Out:
# torch.Size([64, 1, 128, 128])
